# %%
import numpy as np
import scipy 
import pandas as pd
import itertools

# %%
# load information from aafco 
contents = open("AAFCO_cat.txt", "r")
temp = [r[:-1].split(' ') for r in contents.readlines()]
# print(temp)
col_name = ['id', 'Unit(DM based)','Growth Min', 'Adule Maintenance Min', 'Adule Maintenance Max']
# construct df to store AACFO baselines

aafco = pd.DataFrame(temp, columns =col_name)
# check nutrition list
aafco['id'] = aafco['id'].apply(lambda x: x.replace('_', ' '))
# the same type of nutri for home made meal
aafco.drop(index=(26), inplace=True)

# %%
print(aafco[['id', 'Unit(DM based)']])
# Out:
#                                        id Unit(DM based)
# 0                           Crude Protein              g
# 1                                Arginine              g
# 2                               Histidine              g
# 3                              Isoleucine              g
# 4                                 Leucine              g
# 5                                  Lysine              g
# 6                              Methionine              g
# 7                      Methionine-cystine              g
# 8                           Phenylalanine              g
# 9                  Phenylalanine-tyrosine              g
# 10                              Threonine              g
# 11                             Tryptophan              g
# 12                                 Valine              g
# 13                              Crude Fat              g
# 14                          Linoleic acid              g
# 15                   alpha-Linolenic acid              g
# 16                       Arachidonic acid              g
# 17  Eicosapentaenoic+Docosahexaenoic acid              g
# 18                                Calcium              g
# 19                             Phosphorus              g
# 20                              Potassium              g
# 21                                 Sodium              g
# 22                               Chloride              g
# 23                              Magnesium              g
# 24                                   Iron             mg
# 25                      Copper (extruded)             mg
# 27                              Manganese             mg
# 28                                   Zinc             mg
# 29                                 Iodine             mg
# 30                               Selenium             mg
# 31                              Vitamin A             IU
# 32                              Vitamin D             IU
# 33                              Vitamin E             IU
# 34                              Vitamin K             mg
# 35                               Thiamine             mg
# 36                             Riboflavin             mg
# 37                       Pantothenic acid             mg
# 38                                 Niacin             mg
# 39                             Pyridoxine             mg
# 40                             Folic acid             mg
# 41                                 Biotin             mg
# 42                            Vitamin B12             mg
# 43                                Choline             mg
# 44                     Taurine (extruded)              g
# 45                       Taurine (canned)              g

# %%
# we focus on the adult version 
aafco = aafco[['id', 'Unit(DM based)', 'Adule Maintenance Min', 'Adule Maintenance Max']]

# %%
# Have a list of ingredients and their fdc_id in legacy food 
protein = {'chicken, dark meat, cooked': 172376, 'beef, 10% gound, cooked': 174031, 'pork, 14% ground, cooked': 169192}
carb = {'rice, white, cooked': 169711, 'whie potatoes, baked': 170434}
# fat = {}
fiber = {'pumpkin, cooked': 168449, 'chickpea, cooked': 173757, 'Sweet potato, cooked': 168484}

# %%
# read usda nutrition data, for each food, we wish to store a vector of nutrients 
path = './FoodData_Central_sr_legacy_food_csv_2018-04/'
# list of nutriant from aafco 
nutri = list(aafco['id'])

# get a list of nutri id 
nutri_info = pd.read_csv(path + 'nutrient.csv', dtype = {'name' :'str'})
nutri_info.set_index('id')
# read food nutriant 
food_info = pd.read_csv(path + 'food_nutrient.csv')

# %%
# nutri_info.set_index(['id'], inplace = True)
nutri_info.head()
# Out:
#      id                               name unit_name  nutrient_nbr   rank
# 0  2047   Energy (Atwater General Factors)      KCAL         957.0  280.0
# 1  2048  Energy (Atwater Specific Factors)      KCAL         958.0  290.0
# 2  1001                             Solids         G         201.0  200.0
# 3  1002                           Nitrogen         G         202.0  500.0
# 4  1003                            Protein         G         203.0  600.0

# %%
nutri_info['name'] = nutri_info['name'].astype(str)

# %%
# get a list of food we are interested in 
fdc_id_list = list(protein.values()) + list(carb.values()) + list(fiber.values())

# %%
food_info.head()
# Out:
#         id  fdc_id  nutrient_id   amount  data_points  derivation_id  min  \
# 0  1283674  167512         1003     5.88            1           46.0  NaN
# 1  1283675  167512         1007     3.50            1           46.0  NaN
# 2  1283676  167512         1062  1286.00            0           49.0  NaN
# 3  1283677  167512         1079     1.20            1           46.0  NaN
# 4  1283678  167512         1089     2.12            1           46.0  NaN
#
#    max  median footnote  min_year_acquired
# 0  NaN     NaN      NaN                NaN
# 1  NaN     NaN      NaN                NaN
# 2  NaN     NaN      NaN                NaN
# 3  NaN     NaN      NaN                NaN
# 4  NaN     NaN      NaN                NaN

# %%
# get all data needed for analysis, ignore min/max etc
food_info_filtered = food_info[food_info['fdc_id'].apply(lambda x: x in fdc_id_list)][['fdc_id', 'nutrient_id', 'amount']]
def map_nutri_name(x):
    return nutri_info[nutri_info['id'] == x]['name'].item()

food_info_filtered['nutri_name'] = food_info_filtered['nutrient_id'].apply(map_nutri_name)
food_info_filtered.head()
# Out:
#        fdc_id  nutrient_id  amount           nutri_name
# 77714  168449         1261     0.0              SFA 8:0
# 77715  168449         1272     0.0  PUFA 22:6 n-3 (DHA)
# 77716  168449         1278     0.0  PUFA 20:5 n-3 (EPA)
# 77717  168449         1280     0.0  PUFA 22:5 n-3 (DPA)
# 77718  168449         1018     0.0       Alcohol, ethyl

# %%
# prepare 
USDA_nutri = set(food_info_filtered['nutri_name'])

print(USDA_nutri)
# Out:
# {'Energy', 'Copper, Cu', 'Proline', 'MUFA 18:1', 'Fatty acids, total trans-monoenoic', 'Fatty acids, total polyunsaturated', 'PUFA 18:3 n-3 c,c,c (ALA)', 'Calcium, Ca', 'Caffeine', 'Valine', 'Tocotrienol, delta', 'TFA 18:2 t not further defined', 'PUFA 18:3 n-6 c,c,c', 'SFA 17:0', 'MUFA 16:1', 'Alanine', 'Fatty acids, total trans', 'Protein', 'Ash', 'SFA 4:0', 'Vitamin K (phylloquinone)', 'Carotene, alpha', 'Methionine', 'SFA 14:0', 'Magnesium, Mg', 'MUFA 24:1 c', 'Arginine', 'Phosphorus, P', 'Sucrose', 'MUFA 20:1', 'Leucine', 'SFA 16:0', 'SFA 24:0', 'Manganese, Mn', 'Cryptoxanthin, beta', 'Tocotrienol, alpha', 'SFA 20:0', 'Thiamin', 'MUFA 22:1 c', 'Riboflavin', 'PUFA 20:3 n-3', 'Folate, total', 'TFA 22:1 t', 'Theobromine', 'Pantothenic acid', 'Threonine', 'MUFA 18:1 c', 'Cholesterol', 'Retinol', 'Lysine', 'Alcohol, ethyl', 'Vitamin B-6', 'Folic acid', 'Sodium, Na', 'Lactose', 'Tocotrienol, gamma', 'Niacin', 'Carbohydrate, by difference', 'PUFA 20:2 n-6 c,c', 'Vitamin C, total ascorbic acid', 'Vitamin D3 (cholecalciferol)', 'MUFA 17:1', 'Tocotrienol, beta', 'TFA 16:1 t', 'Aspartic acid', 'Cystine', 'PUFA 18:2 CLAs', 'Vitamin B-12', 'Fatty acids, total saturated', 'SFA 22:0', 'Lutein + zeaxanthin', 'MUFA 14:1', 'Tryptophan', 'Galactose', 'PUFA 18:3', 'Glucose', 'Fatty acids, total monounsaturated', 'Vitamin A, IU', 'MUFA 16:1 c', 'Betaine', 'Tyrosine', 'PUFA 20:4', 'SFA 10:0', 'Vitamin D (D2 + D3)', 'Tocopherol, gamma', 'Fatty acids, total trans-polyenoic', 'Glycine', 'Isoleucine', 'Tocopherol, delta', 'PUFA 18:2 n-6 c,c', 'Sugars, Total', 'Hydroxyproline', 'SFA 6:0', 'PUFA 22:4', 'MUFA 15:1', 'PUFA 22:5 n-3 (DPA)', 'Fructose', 'Phenylalanine', 'Vitamin E (alpha-tocopherol)', 'Vitamin D (D2 + D3), International Units', 'Vitamin A, RAE', 'Potassium, K', 'PUFA 20:4 n-6', 'Folate, food', 'Serine', 'Selenium, Se', 'PUFA 18:4', 'SFA 18:0', 'PUFA 20:5 n-3 (EPA)', 'PUFA 20:3', 'Water', 'PUFA 22:6 n-3 (DHA)', 'TFA 18:2 t,t', 'Glutamic acid', 'Tocopherol, beta', 'SFA 8:0', 'PUFA 18:2', 'Histidine', 'Folate, DFE', 'Maltose', 'TFA 18:1 t', 'SFA 12:0', 'Zinc, Zn', 'Iron, Fe', 'Choline, total', 'Vitamin E, added', 'Vitamin K (Dihydrophylloquinone)', 'Carotene, beta', 'Lycopene', 'Fiber, total dietary', 'Starch', 'MUFA 22:1', 'SFA 15:0', 'Vitamin B-12, added', 'Total lipid (fat)'}

# %%
# Use AAFCO list of nutri as columns 
nutri_col = list(aafco['id'])
nutri_map = {}
Ignore_list = ['Taurine (extruded)', 'Taurine (canned)', 'Biotin', 'Chloride', 'Iodine']
for nutri in nutri_col:
    if not nutri in Ignore_list:
        if nutri == 'Linoleic acid':
    #         omega-6 
            nutri_map[nutri] = [t for t in USDA_nutri if 'n-6' in t]
        elif nutri == 'alpha-Linolenic acid':
    #         polyunsaturated n−3 according to wiki
            nutri_map[nutri] = [t for t in USDA_nutri if '(ALA)' in t]
        elif nutri == 'Arachidonic acid':
            nutri_map[nutri] = ['PUFA 20:4 n-6']
        elif nutri == 'Eicosapentaenoic+Docosahexaenoic acid':
            nutri_map[nutri] = [t for t in USDA_nutri if 'EPA' in t or 'DHA' in t]
        elif nutri == 'Pyridoxine':
            nutri_map[nutri] = ['Vitamin B-6']
        elif nutri == 'Copper (extruded)':
            nutri_map[nutri] = [t for t in USDA_nutri if 'Copper' in t]
        elif nutri == 'Methionine':
            nutri_map[nutri] = ['Methionine', 'Cystine']
        elif nutri == 'Methionine-cystine':
            nutri_map[nutri] = ['Cystine']
        elif nutri == 'Crude Fat':
            nutri_map[nutri] = ['Total lipid (fat)']
        elif nutri == 'Vitamin A':
            nutri_map[nutri] = ['Vitamin A, IU']
        elif nutri == 'Vitamin D':
            nutri_map[nutri] = ['Vitamin D (D2 + D3), International Units']
        else: 
            temp = nutri.replace('-', ' ').lower()
            nutri_map[nutri] = [t for t in USDA_nutri if t.replace('-', '').lower() in temp or temp in t.replace('-', '').lower()]

    
nutri_col = list(nutri_map.keys())

# %%
# construct nutri info for each ingredient  
ingredients_info = food_info_filtered.pivot(index = 'fdc_id', columns = 'nutrient_id',  values='amount').fillna(0)
nutri_info.set_index('name', inplace = True)

# %%
# rename columns 
rev_map = {v:k for k, v in nutri_info['id'].to_dict().items()}
ingredients_info.rename(columns = rev_map, inplace = True)

# %%
ingredients_info['Energy']
# Out:
# fdc_id
# 168449      83.0
# 168484     320.0
# 169192    1211.0
# 169711     406.0
# 170434     385.0
# 172376     648.0
# 173757     686.0
# 174031     910.0
# Name: Energy, dtype: float64

# %%
nutri_info.reset_index(inplace = True)

# %%
unit = {}
for n in nutri_col:
    cur_list = nutri_map[n]
#     check unit matches 
    cur_units = list(nutri_info[nutri_info['name'].apply(lambda x :x in cur_list)].unit_name)
    if (len(set(cur_units)) > 1):
        print(n, ' unit inconsistent')
    unit[n] = cur_units[0]
#     convert vitamine E unit 
    if n == 'Vitamin E':
        ingredients_info[n] = ingredients_info['Vitamin E (alpha-tocopherol)']/0.67 + ingredients_info['Vitamin E, added']/0.45
        unit[n] = 'iu'
    else:
        ingredients_info[n] = ingredients_info[cur_list].sum(axis = 1)
data = ingredients_info[nutri_col + ['Energy']]
# data['Energy'] = ingredients_info['Energy']

# %%
data
# Out:
# nutrient_id  Crude Protein  Arginine  Histidine  Isoleucine  Leucine  Lysine  \
# fdc_id
# 168449                0.72     0.039      0.011       0.387    0.626   0.039
# 168484                1.37     0.048      0.027       0.888    1.437   0.058
# 169192               26.69     1.741      1.055      23.132   37.437   2.296
# 169711                2.02     0.168      0.047       1.771    2.867   0.073
# 170434                2.10     0.103      0.035       1.140    1.844   0.109
# 172376               24.24     1.692      0.723      22.305   36.101   2.286
# 173757                8.86     0.835      0.244       6.948   11.243   0.593
# 174031               26.11     1.698      0.848      22.050   35.687   2.161
#
# nutrient_id  Methionine  Methionine-cystine  Phenylalanine  \
# fdc_id
# 168449            0.014               0.002          0.083
# 168484            0.082               0.019          0.279
# 169192            1.637               0.308          5.855
# 169711            0.170               0.041          0.459
# 170434            0.107               0.025          0.275
# 172376            1.542               0.283          5.321
# 173757            0.473               0.119          1.615
# 174031            1.478               0.269          5.920
#
# nutrient_id  Phenylalanine-tyrosine  ...  Vitamin K  Thiamine  Riboflavin  \
# fdc_id                               ...
# 168449                        0.133  ...        0.8     0.031       0.078
# 168484                        0.376  ...        2.1     0.056       0.047
# 169192                        8.558  ...        0.0     0.421       0.486
# 169711                        0.643  ...        0.0     0.020       0.013
# 170434                        0.388  ...        2.7     0.048       0.043
# 172376                        7.683  ...        3.5     0.098       0.222
# 173757                        2.215  ...        4.0     0.116       0.063
# 174031                        8.357  ...        1.1     0.044       0.176
#
# nutrient_id  Pantothenic acid  Niacin  Pyridoxine  Folic acid  Vitamin B12  \
# fdc_id
# 168449                  0.201   0.413       0.044         0.0         0.00
# 168484                  0.581   0.538       0.165         0.0         0.00
# 169192                  0.915   9.286       0.613         0.0         1.02
# 169711                  0.215   0.290       0.026         0.0         0.00
# 170434                  0.383   1.528       0.211         0.0         0.00
# 172376                  1.100   5.598       0.407         0.0         0.38
# 173757                  0.286   0.526       0.139         0.0         0.00
# 174031                  0.658   5.659       0.397         0.0         2.56
#
# nutrient_id  Choline  Energy
# fdc_id
# 168449           6.2    83.0
# 168484          10.8   320.0
# 169192          89.7  1211.0
# 169711           2.1   406.0
# 170434          14.4   385.0
# 172376          70.3   648.0
# 173757          42.8   686.0
# 174031          83.9   910.0
#
# [8 rows x 41 columns]

# %%
nutri_info[nutri_info['name'].apply(lambda x :x in USDA_nutri)].unit_name.apply(lambda x: x.lower())
# Out:
# 4         g
# 5         g
# 6         g
# 8         g
# 9      kcal
#        ...
# 404       g
# 405       g
# 406       g
# 411       g
# 415       g
# Name: unit_name, Length: 136, dtype: object

# %%
# replace non-determined requirement with 0 
aafco.replace('ND', 0, inplace = True)

# %%
# set up constrains based on aafco
aafco_units = aafco.set_index('id')[['Unit(DM based)']].to_dict()['Unit(DM based)']
for v in aafco_units:
    if v in unit:
#         if v == ''
        aafco_unit = aafco_units[v].lower()
        usda_unit = unit[v].lower()
#         print(v, aafco_unit, usda_unit)
        if aafco_unit != usda_unit:
            if  aafco_unit == 'g' and usda_unit == 'mg':
                aafco_units[v] = 'mg'
                aafco[aafco['id'] == v][['Adule Maintenance Min', 'Adule Maintenance Max']].astype(float).apply(lambda x: x * 1000)
            elif aafco_unit == 'mg' and usda_unit == 'ug':
                aafco_units[v] = 'ug'
                aafco[aafco['id'] == v][['Adule Maintenance Min', 'Adule Maintenance Max']].astype(float).apply(lambda x: x * 1000)

# %%
aafco['Adule Maintenance Max'].astype(float)
aafco['Adule Maintenance Min'].astype(float)
A = pd.concat([data, aafco.set_index('id')[['Adule Maintenance Min', 'Adule Maintenance Max']].T])
A
# Out:
#                       Crude Protein Arginine Histidine Isoleucine Leucine  \
# 168449                         0.72    0.039     0.011      0.387   0.626
# 168484                         1.37    0.048     0.027      0.888   1.437
# 169192                        26.69    1.741     1.055     23.132  37.437
# 169711                         2.02    0.168     0.047      1.771   2.867
# 170434                          2.1    0.103     0.035       1.14   1.844
# 172376                        24.24    1.692     0.723     22.305  36.101
# 173757                         8.86    0.835     0.244      6.948  11.243
# 174031                        26.11    1.698     0.848      22.05  35.687
# Adule Maintenance Min            65     2.60      0.78       1.30    3.10
# Adule Maintenance Max          None     None      None       None    None
#
#                       Lysine Methionine Methionine-cystine Phenylalanine  \
# 168449                 0.039      0.014              0.002         0.083
# 168484                 0.058      0.082              0.019         0.279
# 169192                 2.296      1.637              0.308         5.855
# 169711                 0.073       0.17              0.041         0.459
# 170434                 0.109      0.107              0.025         0.275
# 172376                 2.286      1.542              0.283         5.321
# 173757                 0.593      0.473              0.119         1.615
# 174031                 2.161      1.478              0.269          5.92
# Adule Maintenance Min   2.08        0.5               1.00          1.05
# Adule Maintenance Max   None       3.75               None          None
#
#                       Phenylalanine-tyrosine  ... Pyridoxine Folic acid  \
# 168449                                 0.133  ...      0.044        0.0
# 168484                                 0.376  ...      0.165        0.0
# 169192                                 8.558  ...      0.613        0.0
# 169711                                 0.643  ...      0.026        0.0
# 170434                                 0.388  ...      0.211        0.0
# 172376                                 7.683  ...      0.407        0.0
# 173757                                 2.215  ...      0.139        0.0
# 174031                                 8.357  ...      0.397        0.0
# Adule Maintenance Min                   3.83  ...        1.0       0.20
# Adule Maintenance Max                   None  ...       None       None
#
#                       Vitamin B12 Choline  Energy Chloride Iodine Biotin  \
# 168449                        0.0     6.2    83.0      NaN    NaN    NaN
# 168484                        0.0    10.8   320.0      NaN    NaN    NaN
# 169192                       1.02    89.7  1211.0      NaN    NaN    NaN
# 169711                        0.0     2.1   406.0      NaN    NaN    NaN
# 170434                        0.0    14.4   385.0      NaN    NaN    NaN
# 172376                       0.38    70.3   648.0      NaN    NaN    NaN
# 173757                        0.0    42.8   686.0      NaN    NaN    NaN
# 174031                       2.56    83.9   910.0      NaN    NaN    NaN
# Adule Maintenance Min       0.005     600     NaN     0.75   0.15  0.018
# Adule Maintenance Max        None    None     NaN       16   None   None
#
#                       Taurine (extruded) Taurine (canned)
# 168449                               NaN              NaN
# 168484                               NaN              NaN
# 169192                               NaN              NaN
# 169711                               NaN              NaN
# 170434                               NaN              NaN
# 172376                               NaN              NaN
# 173757                               NaN              NaN
# 174031                               NaN              NaN
# Adule Maintenance Min               0.25              0.5
# Adule Maintenance Max               None             None
#
# [10 rows x 46 columns]

# %%
A[nutri_col].to_numpy()[:-2].shape
# Out:
# (8, 40)

# %%
A = A.fillna(0)

# %%
A_low = A[nutri_col].to_numpy()[:-2]
max_bound = list(aafco['id'][aafco['Adule Maintenance Max'].notna()])
A_up = A[max_bound].to_numpy()[:-2]
A_opt = np.concatenate((-A_low, A_up), axis = 1).T

A_eq = A[['Energy']].to_numpy()[:-2].T
A_opt.shape
# Out:
# (45, 8)

# %%
# write aafco constrain
b_low = A[nutri_col].to_numpy()[-2].astype(float)
b_up = A[max_bound].to_numpy()[-2]
b_opt = np.concatenate((-b_low, b_up), axis = 0)
# combined energy is 1000
b_eq = 1000
# obj is to minimize carb 
c = [0 for i in range(A_opt.shape[1])]
for f in carb: 
    i_f = list(data.index).index(carb[f])
    c[i_f] = 1

# %%
print(c)
# Out:
# [0, 0, 0, 1, 1, 0, 0, 0]

# %%
scipy.optimize.linprog(c, A_opt, b_opt, A_eq, b_eq)
# Out:
#        message: The problem is infeasible. (HiGHS Status 8: model_status is Infeasible; primal_status is At lower/fixed bound)
#        success: False
#         status: 2
#            fun: None
#              x: None
#            nit: 0
#          lower:  residual: None
#                 marginals: None
#          upper:  residual: None
#                 marginals: None
#          eqlin:  residual: None
#                 marginals: None
#        ineqlin:  residual: None
#                 marginals: None

# %%
size
# Out:
# 45

# %%
# from recipe in gram
recipe = {'Protein':86, 'carb': 80, 'fiber': 5.69}
rec_v = list(recipe.values())

size = len(nutri_col)
b_up_r = np.zeros(size)
b_low_r = np.zeros(size)
for cur_rec in itertools.product(*[list(protein.values()), list(carb.values()), list(fiber.values())]):
    cur_nutri = np.dot(A[nutri_col].loc[list(cur_rec)].to_numpy().T, rec_v)/100
    b_up_r = np.maximum(cur_nutri, b_up_r)
    b_low_r = np.minimum(cur_nutri, b_up_r)

# %%
A_low_r = A[nutri_col].to_numpy()[:-2] * -1
A_up_r = A[nutri_col].to_numpy()[:-2]
A_opt_r = np.concatenate((A_low_r, A_up_r), axis = 1).T

b_opt_r = np.concatenate((-b_low_r, b_up_r), axis = 0)
# check the shape 
print(A_opt_r.shape, b_opt_r.shape)
# Out:
# (80, 8) (80,)

# %%
opt = scipy.optimize.linprog(c, A_opt_r, b_opt_r)

# %%
temp_dic = fiber | carb | protein
rev_ingredient_map = {v:k for k, v in temp_dic.items()}
ing_list = list(A.index)[:-2]
# display result 
print([(rev_ingredient_map[ing_list[i]], opt.x[i])for i in range(len(ing_list))])
# Out:
# [('pumpkin, cooked', 0.0), ('Sweet potato, cooked', 0.05690000000000048), ('pork, 14% ground, cooked', 0.86), ('rice, white, cooked', 0.0), ('whie potatoes, baked', 0.8000000000000005), ('chicken, dark meat, cooked', -0.0), ('chickpea, cooked', -0.0), ('beef, 10% gound, cooked', -0.0)]

# %%
print(A.columns)
# Out:
# Index(['Crude Protein', 'Arginine', 'Histidine', 'Isoleucine', 'Leucine',
#        'Lysine', 'Methionine', 'Methionine-cystine', 'Phenylalanine',
#        'Phenylalanine-tyrosine', 'Threonine', 'Tryptophan', 'Valine',
#        'Crude Fat', 'Linoleic acid', 'alpha-Linolenic acid',
#        'Arachidonic acid', 'Eicosapentaenoic+Docosahexaenoic acid', 'Calcium',
#        'Phosphorus', 'Potassium', 'Sodium', 'Magnesium', 'Iron',
#        'Copper (extruded)', 'Manganese', 'Zinc', 'Selenium', 'Vitamin A',
#        'Vitamin D', 'Vitamin E', 'Vitamin K', 'Thiamine', 'Riboflavin',
#        'Pantothenic acid', 'Niacin', 'Pyridoxine', 'Folic acid', 'Vitamin B12',
#        'Choline', 'Chloride', 'Iodine', 'Biotin', 'Taurine (extruded)',
#        'Taurine (canned)'],
#       dtype='object')

# %%
# filter some ingredients 
combined_max = set(['Crude Protein','Phosphorus', 'Calcium', 'Sodium'])
combined_max_idx = [A.columns.get_loc(t) for t in combined_max]
A.to_numpy().T[combined_max_idx]
# Out:
# array([[30.0, 32.0, 226.0, 8.0, 75.0, 200.0, 168.0, 202.0, '1.25', 0],
#        [15.0, 27.0, 20.0, 2.0, 10.0, 11.0, 49.0, 13.0, '1.5', 0],
#        [1.0, 27.0, 89.0, 5.0, 7.0, 128.0, 7.0, 68.0, '0.5', 0],
#        [0.72, 1.37, 26.69, 2.02, 2.1, 24.24, 8.86, 26.11, '65', 0]],
#       dtype=object)

# %%
A.to_numpy()[:-2].T[combined_max_idx].shape
# Out:
# (6, 8)

# %%
A_low_r = A[nutri_col].to_numpy()[:-2].T[combined_max_idx] * -1
A_up_r = A[nutri_col].to_numpy()[:-2].T[combined_max_idx]
A_opt_r = np.concatenate((A_low_r, A_up_r), axis = 0)
A_eq = np.ones((1, A.shape[0] - 2))
b_eq = np.sum(rec_v)/100
# b_up_r[0] = 100
b_opt_r = np.concatenate((-b_low_r[combined_max_idx], b_up_r[combined_max_idx]), axis = 0)
# check the shape 
print(A_opt_r.shape, b_opt_r.shape)
c = [0 for i in range(A_opt.shape[1])]
for f in carb: 
    i_f = list(data.index).index(carb[f])
    c[i_f] = 1
for f in protein:
    i_f = list(data.index).index(protein[f])
    c[i_f] = -5
# Out:
# (8, 8) (8,)

# %%
opt_r = scipy.optimize.linprog(c, A_up_r,  b_up_r[combined_max_idx], A_eq, b_eq)
print([(rev_ingredient_map[ing_list[i]], opt_r.x[i])for i in range(len(ing_list))])
# Out:
# [('pumpkin, cooked', 0.7160654962424712), ('Sweet potato, cooked', 0.0), ('pork, 14% ground, cooked', 0.0), ('rice, white, cooked', 0.0), ('whie potatoes, baked', 0.0), ('chicken, dark meat, cooked', 0.8073914708040929), ('chickpea, cooked', 0.0), ('beef, 10% gound, cooked', 0.19344303295343596)]

# %%
opt_r = scipy.optimize.linprog(c, A_opt_r, b_opt_r, A_eq, b_eq)
print([(rev_ingredient_map[ing_list[i]], opt_r.x[i])for i in range(len(ing_list))])
# Out:
# [('pumpkin, cooked', 0.18174430647219753), ('Sweet potato, cooked', 0.0), ('pork, 14% ground, cooked', 0.09650454446894985), ('rice, white, cooked', 0.0), ('whie potatoes, baked', 0.4171129339524098), ('chicken, dark meat, cooked', 0.8130172991105726), ('chickpea, cooked', 0.20852091599587025), ('beef, 10% gound, cooked', 0.0)]
